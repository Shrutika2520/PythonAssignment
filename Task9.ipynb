# %% [markdown]
# # Task_9

# %% [markdown]
# # Q-1. Write an SQL query to show the top n (say 15) records of a table.

# %% [markdown]
# SELECT * FROM worker ORDER BY SALARY DESC LIMIT 15;

# %% [markdown]
# ![Task9-1.PNG](attachment:Task9-1.PNG)

# %% [markdown]
# # Q-2. Write an SQL query to determine the nth (say n=10) highest salary from a table.

# %% [markdown]
# SELECT Salary FROM Worker ORDER BY Salary DESC LIMIT 10,1;

# %% [markdown]
# ![Task9-2.PNG](attachment:Task9-2.PNG)
