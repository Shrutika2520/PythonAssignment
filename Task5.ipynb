# %% [markdown]
# # Task_5

# %% [markdown]
# # Q-1. Write an SQL query to print details of workers excluding first names, “Susan” and “Neena” from Worker table.

# %% [markdown]
# Select * from Worker where FIRST_NAME not in ('Susan','Neena');

# %% [markdown]
# ![Task5-1.PNG](attachment:Task5-1.PNG)

# %% [markdown]
# # Q-2. Write an SQL query to print details of the Workers whose FIRST_NAME ends with ‘e’ and contains six alphabets

# %% [markdown]
# Select * from Worker where FIRST_NAME like '_____e';

# %% [markdown]
# ![Task5-2.PNG](attachment:Task5-2.PNG)

# %% [markdown]
# # Q-3. Write a query to validate Email of Employee (email should have first name last name and guvi.com example (first name=Kamal last name= raja and the mail id should be kamalraja@guvi.com).

# %% [markdown]
# SELECT * FROM worker WHERE email NOT LIKE '%@guvi.com%';

# %% [markdown]
# ![Task5-3-2.PNG](attachment:Task5-3-2.PNG)
