# %% [markdown]
# # Task_6

# %% [markdown]
# # Q-1. Write an SQL query`m to print details of the Workers who have joined in March’2021.

# %% [markdown]
# select * from worker where JOINING_DATE between '2021-03-01' and '2021-03-31' order by JOINING_DATE;

# %% [markdown]
# ![Task6-1.PNG](attachment:Task6-1.PNG)

# %% [markdown]
# # Q-2. Write an SQL query to fetch duplicate records having matching data in some fields of a table.

# %% [markdown]
# SELECT DEPARTMENT , COUNT(DEPARTMENT) FROM worker GROUP BY DEPARTMENT HAVING COUNT(DEPARTMENT) > 1;

# %% [markdown]
# ![Task6-2.PNG](attachment:Task6-2.PNG)

# %% [markdown]
# # Q-3. How to remove duplicate rows from Employees table.

# %% [markdown]
# DELETE c1 FROM worker c1 INNER JOIN worker c2 WHERE c1.salary > c2.salary AND c1.LAST_NAME = c2.LAST_NAME;

# %% [markdown]
# ![Task6-3.PNG](attachment:Task6-3.PNG)
